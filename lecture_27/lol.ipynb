# %%
import kagglehub
import pandas as pd
import matplotlib.pyplot as plt

# Download latest version
path = kagglehub.dataset_download("ratin21/nba-player-salaries-2024-25")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/bryancamargo/.cache/kagglehub/datasets/ratin21/nba-player-salaries-2024-25/versions/1

# %%
df = pd.read_csv("data/NBA_Player_Salaries_2024-25_1.csv")

df_2 = pd.read_csv("data/database_24_25.csv")

df_2_player_filtered_boston = df_2.query("Tm == 'BOS'")

players_fg = df_2_player_filtered_boston["FG%"]

df_1_salaries = df.query("Team == 'BOS'")

salaries = df_1_salaries.sort_values(by = "Salary" , ascending = True)

plt.plot("players_fg", "salaries" )
# Out:
#               Player   Tm  Opp Res     MP  FG  FGA    FG%  3P  3PA  ...  DRB  \
# 0       Jayson Tatum  BOS  NYK   W  30.30  14   18  0.778   8   11  ...    4
# 2      Derrick White  BOS  NYK   W  26.63   8   13  0.615   6   10  ...    3
# 3       Jrue Holiday  BOS  NYK   W  30.52   7    9  0.778   4    6  ...    2
# 6       Jaylen Brown  BOS  NYK   W  29.90   7   18  0.389   5    9  ...    5
# 9         Al Horford  BOS  NYK   W  26.08   4    7  0.571   3    5  ...    3
# ...              ...  ...  ...  ..    ...  ..  ...    ...  ..  ...  ...  ...
# 16324  Drew Peterson  BOS  DAL   L   9.58   1    1  1.000   1    1  ...    1
# 16328  Neemias Queta  BOS  DAL   L   9.58   3    6  0.500   0    0  ...    0
# 16330     Sam Hauser  BOS  DAL   L  20.70   2    5  0.400   2    5  ...    1
# 16336   Jordan Walsh  BOS  DAL   L   9.58   1    2  0.500   0    1  ...    2
# 16350     Al Horford  BOS  DAL   L  20.88   1    4  0.250   1    3  ...    5
#
# ...

# %%
print(len(df))
print(len(df_2))

df_2.sorted = df_2.groupby()
# Out:
# 563
# 16512

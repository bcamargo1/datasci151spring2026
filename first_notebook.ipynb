# %% [markdown]
# This is my first jupyter notebook

# %%
print("My name is Bryan Camargo")
# Out:
# My name is Bryan Camargo

# %% [markdown]
# # This is my first jupyter notebook

# %% [markdown]
# # This is my first jupyter notebook

# %% [markdown]
# ###### This is my first jupyter notebook

# %%
print("Hello World!")
# Out:
# Hello World!
